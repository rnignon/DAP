# %% [markdown]
# <a href="https://colab.research.google.com/github/rnignon/DAP/blob/main/graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

seqT = pd.read_csv('https://raw.githubusercontent.com/rnignon/Quic/main/seq.csv')
df = pd.DataFrame(data = seqT.seqN.array, index = seqT.time, columns = ['seq'])

# %%
def plot_df(x, y, title="", xlabel='time', ylabel='seq', dpi=100):
    plt.figure(figsize=(10,3), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

plot_df(x=df.index, y=df.seq,
        title='Seq')
